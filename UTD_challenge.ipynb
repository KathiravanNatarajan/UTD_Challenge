# %%
import numpy as np 
import pandas as pd 
train_Set = pd.read_excel('Training Dataset.xlsx')
train_Set.head()
# Out:
#    Id Education Level  Age Age Range   Employment Status  Gender  Children  \
# 0   1     High School   51     50-59          Unemployed  Female         0
# 1   2        Bachelor   42     40-49            Employed  Female         2
# 2   3          Master   47     40-49            Employed    Male         0
# 3   4    Some College   21     20-29            Employed  Female         0
# 4   5     High School   49     40-49  Not in labor force  Female         0
#
#    Weekly Earnings  Year  Weekly Hours Worked    ...      \
# 0                0  2005                    0    ...
# 1             1480  2005                   40    ...
# 2              904  2005                   40    ...
# 3              320  2005                   40    ...
# 4                0  2005                    0    ...
#
#    Playing with Children  Job Searching  Shopping  Eating and Drinking  \
# 0                      0              0         0                   40
# ...

# %%
list(train_Set)
# Out:
# ['Id',
#  'Education Level',
#  'Age',
#  'Age Range',
#  'Employment Status',
#  'Gender',
#  'Children',
#  'Weekly Earnings',
#  'Year',
#  'Weekly Hours Worked',
#  'Sleeping',
#  'Grooming',
#  'Housework',
#  'Food & Drink Prep',
#  'Caring for Children',
#  'Playing with Children',
#  'Job Searching',
#  'Shopping',
#  'Eating and Drinking',
#  'Socializing & Relaxing',
#  'Television',
#  'Golfing',
#  'Running',
#  'Volunteering',
#  'Total']

# %%
# Feature Engineering 
new_df = pd.get_dummies(train_Set, columns=['Education Level','Employment Status','Age Range','Gender'])
new_df = new_df.fillna(0)
new_df.head()
# Out:
#    Id  Age  Children  Weekly Earnings  Year  Weekly Hours Worked  Sleeping  \
# 0   1   51         0                0  2005                    0       825
# 1   2   42         2             1480  2005                   40       500
# 2   3   47         0              904  2005                   40       480
# 3   4   21         0              320  2005                   40       705
# 4   5   49         0                0  2005                    0       470
#
#    Grooming  Housework  Food & Drink Prep     ...       Age Range_0-19  \
# 0        80        150                 45     ...                    0
# 1        10        150                 60     ...                    0
# 2        70          1                  0     ...                    0
# 3        65         90                135     ...                    0
# 4        60        205                 15     ...                    0
#
#    Age Range_20-29  Age Range_30-39  Age Range_40-49  Age Range_50-59  \
# ...

# %%
train_X = new_df.drop(['Total'],axis=1)
train_y = new_df['Total']

# %%
from sklearn import linear_model
regr = linear_model.LinearRegression()
regr.fit(train_, diabetes_y_train)

# Make predictions using the testing set
diabetes_y_pred = regr.predict(diabetes_X_test)
